# %%
# %% network expansion algorithm
# % author: Joshua Goldford
# % date: 11-6-2015
#
# % inputs: R := reactant binary matrix (m x n)
# %         P := product binary matrix (m x n)
# %         x := starting point (binary vector (m x 1)
# %         b := total number of reactant vector (n x 1) (can be computed via
# %         row sums on R)
# % output: out := output structure containing following fields:
# %              x := binary vector representing presence/absence of metabolites
# %                   in converged network
# %              y := binary vector representing presence/absence of reactions
# %                   in converged network
# %              X := (metabolite accumulation matrix) binary mxr matrix
# %                   representing the presence/absence of metabolites at
# %                   iteration r
# %              Y := (reaction accumulation matrix) binary mxr matrix
# %                   representing the presence/absence of reactions at
# %                   iteration r
#
#
# function [out] = netExp(R,P,x,b)
#
# % initialize variables:
# % find the total number of metabolites in the seed set
# k = sum(x);
# % initialize previous iteration count of metabolites in the network
# k0 = 0;
# % iteration 1 consistes of the seed set
# X = x;
# % initialize reaction accumulation matrix
# Y = [];
#
# % while the metabolite set has not converged
# while k > k0
#     % update previous number of metabolites
#     k0 = k;
#     % R'x ==> represnts the number of present metabolites in the
#     % network within each reaction; if this isequal to the total
#     % number of metabolites in each reaction, then the reaction
#     % is added to the network
#     y  = double(R'*x == b);
#
#     % P*y > 0 ==> represents the vector of reactions that produce
#     % metabolite i. (i in 1:m).  If this is >0,
#     % then that metabolite is producable
#     x_new = double(P*y > 0);
#     % add to previous set of meatabolites (only needed to retain seed set)
#     x = double(x | x_new);
#     % find new total number of metabolites in network
#     k = sum(x);
#
#     % append accumulation matricies
#     X = [X,x];
#     Y = [Y,y];
# end
#
# % parse variables into output structure
# out.x = x;
# out.y = y;
# out.X = X;
# out.Y = Y;
#
#
#
# end

# %%
import json
import collections
import re
import os
import glob

# %%
def load_json(fname):
    """
    Wrapper to load json in single line

    :param fname: the filepath to the json file
    """
    with open(fname) as f:
        return json.load(f)

# %%
archaea_metadata = load_json("../jgi/metadata/archaea_metadata.json")
bacteria_metadata = load_json("../jgi/metadata/bacteria_metadata_subset.json")
eukarya_metadata = load_json("../jgi/metadata/eukarya_metadata.json")

# %%
for k in archaea_metadata:
    print k
# Out:
# sort
# totalRecords
# checked
# pageSize
# recordsReturned
# records
# startIndex
# filtChecked
# allSelect
# dir

# %%
len([k for k in archaea_metadata['records']])
# Out:
# 1625

# %%
for k in archaea_metadata['records']:
    for category in k:
        print category
    break
# Out:
# Enzymeassembled
# IMGProductAssignment
# MetaCycCountassembled
# ContactNameDisp
# BiosyntheticClusterGeneassembledDisp
# ProportalWOASalinity
# GenomeProperty
# SampleBodySubsiteDisp
# SpecificEcosystem
# COGClusterCountassembledDisp
# RevisedCountDisp
# GOLDSequencingProjectIDDisp
# SampleBodySiteDisp
# DomainDisp
# Sporulation
# UncharCountDisp
# FundingProgram
# PfamClusterCountassembledDisp
# GOLDAnalysisProjectID
# ITSSPIDDisp
# Comments
# MetabolismDisp
# RNAassembled
# SporulationDisp
# SequencingCenter
# JGIProjectIDITSSPIDDisp
# Select
# CodingBaseCountNP127
# Alt2ContactEmails
# KOGCountDisp
# BioticRelationshipsDisp
# KOGCount
# CladeDisp
# TransmembraneCount
# MyIMGAnnotation
# 23SrRNACountassembledDisp
# wFuncPredCountassembled
# NitrateConcentrationDisp
# ProportalIsolation
# HostGender
# ProportalOcean
# NCBIProjectIDDisp
# GOLDSequencingDepth
# ChromosomalCassetteGeneCountDisp
# IMGPartsListCountDisp
# StrainDisp
# OrthologsCountDisp
# LonghurstCodeDisp
# Fused
# CodingBaseCountassembledDisp
# JGIAnalysisProductName
# PfamCountassembledDisp
# PMOProjectIDDisp
# ParalogGroupCountDisp
# AltContactEmailDisp
# CDSCountassembledDisp
# ScaffoldCountassembledDisp
# NotKOassembledDisp
# GramStainingDisp
# SequencingMethodDisp
# OtherRNACountassembled
# Clade
# ChromosomalCassetteCount
# BiosyntheticClusterCountassembled
# GenusDisp
# Isolation
# GOLDSequencingQualityDisp
# wofunctionpredictionassembled149Disp
# MyIMGAnnotationDisp
# PhenotypeDisp
# KOGClusterCountDisp
# Family
# SequencingMethod
# IMGTermDisp
# Dubious
# CombinedSample
# KOassembled
# EnzymeCountassembled
# JGIAnalysisProductNameDisp
# Motility
# pHDisp
# PfamCountassembled
# Cultured
# AltContactNameDisp
# KOGClusterCount
# ProportalWOASilicate
# wFuncPredassembledDisp
# NCBITaxonID
# StudyNameDisp
# IMGTerm
# AddDateDisp
# TIGRfamassembled
# HostName
# OrthologGroupCount
# CellArrangementDisp
# CRISPRCountassembled
# GCassembled
# AssemblyMethodDisp
# Species
# CodingBaseCountassembled
# IMGTermCountDisp
# FusedDisp
# GeographicLocationDisp
# GenomeSizeassembled
# FundingYearDisp
# KOassembledDisp
# SpecificEcosystemDisp
# SampleBodySite
# 16SrRNACountassembledDisp
# SubmissionTypeDisp
# 28SrRNACountassembledDisp
# RevisedCount
# GOLDAnalysisProjectTypeDisp
# HorizontallyTransferredCountDisp
# SequencingStatusDisp
# RNACountassembled
# Relevance
# CDSCountassembled
# IMGClusterDisp
# LonghurstDescriptionDisp
# FundingProgramDisp
# CodingBaseCountNPDisp
# EcosystemTypeDisp
# Pressure
# AltitudeInMetersDisp
# GenomeBinCountassembledDisp
# MotilityDisp
# tRNACountassembledDisp
# GOLDAnalysisProjectIDDisp
# Longitude
# Salinity
# ProportalWOASilicateDisp
# SeqStatusDisp
# GOLDAnalysisProjectType
# IMGPathwawyCountDisp
# Habitat
# IsolationCountryDisp
# IsPublic
# IMGPartsListDisp
# ObsoleteCount
# StudyName
# ParalogsCount
# OxygenconcentrationDisp
# CellArrangement
# GPTSProposalID
# NCBITaxonIDDisp
# NCBIBiosampleAccession
# Latitude
# IsolationCountry
# Orthologs
# IsolationDisp
# ProjectStudyNameDisp
# CodingBaseCountassembled125Disp
# Class
# UnculturedTypeDisp
# FusedCountDisp
# Unchar
# KEGGCountassembledDisp
# MyIMGAnnotationCountDisp
# RNACountassembledDisp
# PressureDisp
# EnergySource
# FusedCount
# Alt2ContactNames
# HostNameDisp
# ITSProposalID
# LonghurstDescription
# FusionComponentCount
# GCassembledDisp
# ProportalWOANitrateDisp
# RNAassembledDisp
# GenomePropertyDisp
# OrthologsDisp
# HostGenderDisp
# ChromosomalCassetteCountDisp
# Alt2ContactEmailsDisp
# GenomeNameSampleName
# NCBIProjectID
# ProportalIsolationDisp
# HorizontallyTransferredCount
# RevisedDisp
# ProportalStationDisp
# IMGClusterCount
# MetaCycCountassembledDisp
# IMGRelease
# EnergySourceDisp
# GOLDSequencingStrategyDisp
# HabitatDisp
# ChromosomalCassetteGene
# RefSeqProjectIDDisp
# ProportalWOADissolvedOxygenDisp
# ProjectStudyName
# IMGTermCount
# Diseases
# GOLDSequencingDepthDisp
# DubiousCountDisp
# tRNACountassembled
# wofunctionpredictionassembled
# SampleCollectionDate
# SequencingStatus
# NotKOCountassembled
# LongitudeDisp
# SalinityDisp
# SignalPeptideCount
# NotMetaCycCountassembled
# EcosystemType
# ProportalWOASalinityDisp
# Genus
# NotMetaCycCountassembledDisp
# COGCountassembledDisp
# AltContactName
# ProportalWOAPhosphateDisp
# GenomePropertyCountDisp
# Obsolete
# DistanceMatrixCalcDate
# CodingBaseCountNP
# DepthInMetersDisp
# EcosystemSubtype
# NotKOassembled
# ITSProposalIDDisp
# MetaCycassembled
# ProportalWOADissolvedOxygen
# CulturedDisp
# KOGDisp
# rRNACountassembled
# OxygenRequirement
# KOCountassembled
# COGassembledDisp
# COGassembled
# ParalogGroupCount
# FamilyDisp
# ProportalWOATemperature
# GramStaining
# Alt2ContactNamesDisp
# InterPro
# ClassDisp
# NCBIBioprojectAccessionDisp
# OrthologGroupCountDisp
# ObsoleteCountDisp
# ProportalOceanDisp
# GCCountassembledDisp
# Transmembrane
# SignalPeptideCountDisp
# GOLDStudyIDDisp
# BioticRelationships
# PMOProjectID
# TIGRfamClusterCountassembledDisp
# MedicalRecordNumberDisp
# Metabolism
# BiosyntheticClusterGeneCountassembledDisp
# HorizontallyTransferredDisp
# NitrateConcentration
# ProportalWOAPhosphate
# InterProCountDisp
# FundingAgency
# GeneCountassembled
# Chlorophyllconcentration
# PseudoGenesCount
# EcotypeDisp
# DubiousDisp
# TemperatureRange
# FundingYear
# SeqStatus
# PseudoGenesCountDisp
# NotKEGGCountassembledDisp
# Strain
# InterProDisp
# GOLDStudyID
# DiseasesDisp
# wFuncPredassembled
# CodingBaseCountNP127Disp
# pH
# ChromosomalCassetteGeneDisp
# EcosystemSubtypeDisp
# PseudoGenes
# Paralogs
# PhylumDisp
# IMGGenomeIDDisp
# IMGPathwawyCount
# wofunctionpredictionassembledDisp
# PfamClusterCountassembled
# ChlorophyllconcentrationDisp
# IMGPartsList
# NotMetaCycassembledDisp
# TransmembraneCountDisp
# AssemblyMethod
# SampleCollectionTemperature
# wFuncPredCountassembledDisp
# GenomeBinCountassembled
# GeneCountassembledDisp
# CultureTypeDisp
# CellShape
# SampleCollectionTemperatureDisp
# _img_yuirow_id
# GenomeCompletenessDisp
# Phylum
# TransmembraneDisp
# IMGClusterCountDisp
# CultureType
# IMGGenomeID
# PseudoGenesDisp
# ProportalStation
# SpeciesDisp
# ITSSPID
# IMGSubmissionIDDisp
# JGIProjectIDITSSPID
# JGIAnalysisProjectType
# KEGGCountassembled
# MyIMGAnnotationCount
# RelevanceDisp
# ProportalWOATemperatureDisp
# OtherRNACountassembledDisp
# TIGRfamassembledDisp
# CDSassembledDisp
# HMPID
# FusioncomponentDisp
# 5SrRNACountassembled
# rRNACountassembledDisp
# Pfamassembled
# Order
# LonghurstCode
# GeneModelQCDisp
# GeographicLocation
# GenomeSizeassembledDisp
# 5SrRNACountassembledDisp
# HighQuality
# HMPIDDisp
# FusionComponentCountDisp
# SequencingCenterDisp
# CellShapeDisp
# ChromosomalCassetteGeneCount
# 23SrRNACountassembled
# MedicalRecordNumber
# ParalogsCountDisp
# ParalogsDisp
# CombinedSampleDisp
# ContactEmailDisp
# IMGPartsListCount
# TypeStrainDisp
# FundingAgencyDisp
# SubmissionType
# OrderDisp
# Ecosystem
# SignalPeptide
# ProportalWOANitrate
# SampleBodySubsite
# PfamassembledDisp
# GCCountassembled
# CDSassembled
# Revised
# TemperatureRangeDisp
# IMGSubmissionID
# SalinityConcentration
# OxygenRequirementDisp
# KOCountassembledDisp
# NCBIBioprojectAccession
# Phenotype
# HorizontallyTransferred
# HighQualityDisp
# CodingBaseCountassembled125
# NotKOCountassembledDisp
# GPTSProposalIDDisp
# CommentsDisp
# MetaCycassembledDisp
# UncharCount
# 18SrRNACountassembledDisp
# Oxygenconcentration
# COGCountassembled
# EcosystemCategory
# GenomePropertyCount
# Domain
# KEGGassembledDisp
# EcosystemCategoryDisp
# IMGCluster
# InterProCount
# LatitudeDisp
# DistanceMatrixCalcDateDisp
# TypeStrain
# DepthInMeters
# AddDate
# COGClusterCountassembled
# DubiousCount
# TIGRfamCountassembled
# GenomeNameSampleNameDisp
# KEGGassembled
# UnculturedType
# ObsoleteDisp
# NotKEGGassembled
# Visits
# EnzymeassembledDisp
# ContactEmail
# OrthologsCount
# NotKEGGassembledDisp
# BiosyntheticClusterGeneassembled
# EnzymeCountassembledDisp
# AltContactEmail
# ReleaseDateDisp
# ScaffoldCountassembled
# IMGPathway
# GenomeCompleteness
# JGIAnalysisProjectTypeDisp
# Ecotype
# Fusioncomponent
# NCBIBiosampleAccessionDisp
# IMGReleaseDisp
# IMGPathwayDisp
# IMGProductAssignmentDisp
# GeneModelQC
# wofunctionpredictionassembled149
# BiosyntheticClusterGeneCountassembled
# BiosyntheticClusterCountassembledDisp
# VisitsDisp
# AltitudeInMeters
# GOLDSequencingQuality
# EcosystemDisp
# TIGRfamClusterCountassembled
# ReleaseDate
# ContactName
# 16SrRNACountassembled
# 28SrRNACountassembled
# GOLDSequencingStrategy
# NotKEGGCountassembled
# GOLDSequencingProjectID
# SignalPeptideDisp
# IsPublicDisp
# 18SrRNACountassembled
# SalinityConcentrationDisp
# NotMetaCycassembled
# SampleCollectionDateDisp
# KOG
# UncharDisp
# CRISPRCountassembledDisp
# RefSeqProjectID
# TIGRfamCountassembledDisp

# %%
for entry in archaea_metadata['records']:
    print entry['pH']
# Out:
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
#
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 9
# zzz
# zzz
# 2.0 - 4.5
# 7.0 - 7.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 9.0 - 9.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 2-3
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 9
# zzz
# zzz
# 7.5
# zzz
# zzz
# zzz
# zzz
# 6.65
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 8.0
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 5.5
# 6.07
# zzz
# 5.4
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 2-3
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.5
# 6.02
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 2.0 - 4.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.02
# zzz
# zzz
# zzz
# zzz
# 5.5 - 8.5
# zzz
# zzz
# zzz
# zzz
# zzz
# 7.0
# zzz
# zzz
# zzz
# 3
# zzz
# 6.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.5
# zzz
# zzz
# zzz
# 9.5
# zzz
# zzz
# zzz
# 7.3
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.5 - 7.0
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 7.5
# zzz
# 3.6
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.5
# zzz
# zzz
# zzz
# zzz
# zzz
# 9
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.02
# 6.5
# zzz
# zzz
# 6.5
# zzz
# zzz
# zzz
# 6.65
# zzz
# zzz
# zzz
# zzz
# zzz
# 9
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 5.5 - 7.5
# 6.83
# zzz
# zzz
# 7.5
# zzz
# zzz
# 6.02
# zzz
# zzz
# 6 - 8
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 8.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 9.0 - 9.5
# zzz
# zzz
# 7.5
# 7.0?7.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 9.0
# zzz
# zzz
# zzz
# 5.5 - 6.0
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 7.0-7.2
# zzz
# zzz
# 5.5 - 7
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 0.5 - 4
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.02
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 2.0
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 7.0 - 7.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 4.0 - 4.5
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# zzz
# 6.37

# %%
collections.Counter([entry['pH'] for entry in archaea_metadata['records']])
# Out:
# Counter({u'0-3.5': 1,
#          u'0.5 - 4': 1,
#          u'0.7': 1,
#          u'1 - 4': 1,
#          u'1 - 6': 1,
#          u'2': 1,
#          u'2 - 3': 1,
#          u'2 - 4.5': 1,
#          u'2-3': 9,
#          u'2.0': 2,
#          u'2.0 - 4.5': 2,
#          u'2.5 - 3': 1,
#          u'2.7': 3,
#          u'3': 3,
#          u'3.0': 1,
#          u'3.5': 1,
#          u'3.5 - 4.0': 1,
#          u'3.6': 1,
#          u'4 - 6': 1,
#          u'4.0': 1,
#          u'4.0 - 4.5': 1,
#          u'4.5 - 8.5': 1,
#          u'4.6 - 7.5': 1,
#          u'5 - 9': 2,
#          u'5.0-7.4': 1,
#          u'5.2 - 7': 1,
#          u'5.2?8.0': 1,
#          u'5.4': 4,
#          u'5.5': 3,
#          u'5.5 - 6.0': 1,
#          u'5.5 - 7': 1,
#          u'5.5 - 7.5': 1,
#          u'5.5 - 8': 1,
#          u'5.5 - 8.5': 1,
#          u'5.5-8.0': 1,
#          u'5.8': 1,
#          u'5.8 - 9.0': 2,
#          u'6': 2,
#          u'6 - 8': 1,
#          u'6 - 8.5': 1,
#          u'6-8': 1,
#          u'6.0': 1,
#          u'6.0 - 6.5': 1,
#          u'6.0 - 8.0': 1,
#          u'6.0-9.0': 1,
#          u'6.02': 7,
#          u'6.07': 1,
#          u'6.1': 1,
#          u'6.37': 1,
#          u'6.4': 1,
#          u'6.5': 35,
#          u'6.5 - 7': 1,
#          u'6.5 - 7.0': 3,
#          u'6.5 - 7.5': 1,
#          u'6.5 - 7.9': 1,
#          u'6.5 - 8': 4,
#          u'6.5-7.8': 1,
#          u'6.6 - 7.0': 1,
#          u'6.65': 4,
#          u'6.7': 1,
#          u'6.8': 2,
#          u'6.83': 2,
#          u'6.9': 1,
#          u'7': 10,
#          u'7 - 10': 1,
#          u'7,2 - 7.6': 1,
#          u'7.0': 1,
#          u'7.0 - 7.5': 3,
#          u'7.0 - 7.7': 1,
#          u'7.0 - 8.0': 3,
#          u'7.0-7.2': 1,
#          u'7.0-7.5': 2,
#          u'7.03': 2,
#          u'7.0?7.5': 1,
#          u'7.1': 1,
#          u'7.2 - 7.8': 2,
#          u'7.3': 2,
#          u'7.4': 1,
#          u'7.5': 10,
#          u'7.5 - 7.8': 1,
#          u'7.5 - 8.0': 1,
#          u'8.0': 2,
#          u'8.5': 3,
#          u'8.7 - 9.2': 1,
#          u'9': 11,
#          u'9.0': 3,
#          u'9.0 - 9.5': 5,
#          u'9.5': 2,
#          u'zzz': 1419})

# %%
collections.Counter([entry['pH'] for entry in bacteria_metadata['records']])
# Out:
# Counter({u'1.3 - 4.0': 1,
#          u'1.8': 2,
#          u'1.9': 1,
#          u'10': 1,
#          u'11.0': 1,
#          u'2': 3,
#          u'2-2.5 (optimum)': 1,
#          u'2.5': 1,
#          u'3': 4,
#          u'3 - 4': 2,
#          u'3.1-6.5, optimum 4.5-5.0': 1,
#          u'3.2-7.5': 1,
#          u'3.5 - 9.0': 1,
#          u'3.5-3.8': 1,
#          u'3.5-6.0': 1,
#          u'3.6': 1,
#          u'3.6 - 7.8': 1,
#          u'3.6-6.9': 1,
#          u'3.7-7.1': 1,
#          u'3.8-9.0': 1,
#          u'3.85 - 6.35': 1,
#          u'3.9': 1,
#          u'4 - 10': 1,
#          u'4 - 4.5': 1,
#          u'4 - 5': 1,
#          u'4-10': 2,
#          u'4-4.5': 1,
#          u'4-5': 3,
#          u'4-6': 1,
#          u'4-7': 1,
#          u'4-8': 2,
#          u'4-9': 4,
#          u'4-9.6': 2,
#          u'4.0-8.0': 1,
#          u'4.0-8.5': 3,
#          u'4.0-9.0': 1,
#          u'4.0-9.5': 4,
#          u'4.1-7.8': 2,
#          u'4.19': 13,
#          u'4.2 - 7.2': 1,
#          u'4.2 - 8.2': 1,
#          u'4.2-8.3': 1,
#          u'4.29': 3,
#          u'4.3': 1,
#          u'4.5': 7,
#          u'4.5 - 7': 1,
#          u'4.5 - 7.1': 2,
#          u'4.5 - 9.0': 1,
#          u'4.5-12.0': 1,
#          u'4.5-5.0': 1,
#          u'4.5-7.0': 1,
#          u'4.5-8': 3,
#          u'4.5-8.0': 1,
#          u'4.5-8.4': 1,
#          u'4.5-8.5': 2,
#          u'4.7 - 8.8': 1,
#          u'4.7-9.5': 1,
#          u'4.8 - 6.8': 1,
#          u'4.8-8.6': 1,
#          u'4.9-5.4': 1,
#          u'4.9-6.8': 1,
#          u'5': 2,
#          u'5 - 10': 1,
#          u'5 - 6.2': 2,
#          u'5 - 7': 2,
#          u'5 - 7.5': 1,
#          u'5 - 9': 1,
#          u'5- 10': 1,
#          u'5-10': 14,
#          u'5-11': 2,
#          u'5-12': 2,
#          u'5-7': 2,
#          u'5-8': 121,
#          u'5-8.5': 1,
#          u'5-9': 15,
#          u'5-9.5': 1,
#          u'5.0': 1,
#          u'5.0- 10.0; 6.0- 7.0': 3,
#          u'5.0-10.0': 1,
#          u'5.0-10.5': 1,
#          u'5.0-6.5': 2,
#          u'5.0-8.0': 1,
#          u'5.0-8.5': 6,
#          u'5.0-9.0': 1,
#          u'5.0-9.5': 2,
#          u'5.0-9.8': 1,
#          u'5.1-8.0': 1,
#          u'5.1-9.1': 1,
#          u'5.2-7.4': 1,
#          u'5.2-8.6': 1,
#          u'5.3': 1,
#          u'5.3 - 7.6': 1,
#          u'5.3- 7.2': 2,
#          u'5.3-5.5': 2,
#          u'5.3-8.8': 1,
#          u'5.3-9.3': 1,
#          u'5.4-7.5': 1,
#          u'5.4-8.4': 1,
#          u'5.4-8.9': 1,
#          u'5.5': 5,
#          u'5.5 - 10': 1,
#          u'5.5 - 7.5': 5,
#          u'5.5 - 9.5': 1,
#          u'5.5 -7.5': 1,
#          u'5.5-10.0': 2,
#          u'5.5-10.00 (optimum 7.5)': 1,
#          u'5.5-10.5': 1,
#          u'5.5-11': 1,
#          u'5.5-11.0': 3,
#          u'5.5-12.0': 1,
#          u'5.5-12.5': 1,
#          u'5.5-6.0': 2,
#          u'5.5-7.5': 5,
#          u'5.5-8.0': 4,
#          u'5.5-8.3': 1,
#          u'5.5-8.5': 6,
#          u'5.5-8.6': 1,
#          u'5.5-9.0': 9,
#          u'5.5-9.3': 1,
#          u'5.5-9.5': 5,
#          u'5.5-9.7': 1,
#          u'5.6 - 10.1': 1,
#          u'5.6-7.8': 1,
#          u'5.6-8.3': 3,
#          u'5.6-8.4': 2,
#          u'5.6-8.6': 2,
#          u'5.6-9.8': 1,
#          u'5.7 - 6.2': 1,
#          u'5.7-10.0': 1,
#          u'5.7-6.7': 1,
#          u'5.7-8.0': 2,
#          u'5.8 - 6.2': 1,
#          u'5.8 - 8.2': 2,
#          u'5.8-10.0': 1,
#          u'5.8-11': 1,
#          u'5.8-7.8': 1,
#          u'5.8-8.0': 1,
#          u'5.8-8.2': 1,
#          u'5.8-8.8': 1,
#          u'5.8-9.0': 1,
#          u'5.9': 2,
#          u'5.9-8.2': 1,
#          u'5.9-8.8': 2,
#          u'5.9-9.0': 1,
#          u'5.91': 2,
#          u'6': 6,
#          u'6 - 10': 1,
#          u'6 - 6.5': 1,
#          u'6 - 7': 1,
#          u'6 - 8': 2,
#          u'6 - 9': 2,
#          u'6 - 9.2': 1,
#          u'6-10': 15,
#          u'6-11': 8,
#          u'6-12': 1,
#          u'6-7': 7,
#          u'6-8': 27,
#          u'6-9': 34,
#          u'6-9.5': 2,
#          u'6.0': 2,
#          u'6.0 - 10.0': 1,
#          u'6.0 - 7.0': 2,
#          u'6.0 - 8.0': 2,
#          u'6.0 - 8.2': 2,
#          u'6.0 - 9.0': 1,
#          u'6.0 - 9.5': 1,
#          u'6.0-10.0': 3,
#          u'6.0-10.5': 3,
#          u'6.0-6.5': 1,
#          u'6.0-7.0': 1,
#          u'6.0-7.2': 1,
#          u'6.0-7.5': 6,
#          u'6.0-7.8': 1,
#          u'6.0-8.0': 2,
#          u'6.0-8.1': 1,
#          u'6.0-8.2': 1,
#          u'6.0-8.5': 4,
#          u'6.0-8.6': 1,
#          u'6.0-9.5': 3,
#          u'6.0-9.7': 1,
#          u'6.1-10.1': 1,
#          u'6.1-7.5': 1,
#          u'6.1-8.1': 1,
#          u'6.1-8.2': 2,
#          u'6.2-7': 10,
#          u'6.2-8.0': 2,
#          u'6.2-8.2': 1,
#          u'6.2-8.7': 1,
#          u'6.2-8.9': 1,
#          u'6.25': 1,
#          u'6.25-7.5': 1,
#          u'6.3': 43,
#          u'6.3 - 7.4': 2,
#          u'6.3 - 7.5': 1,
#          u'6.3 - 9.3': 1,
#          u'6.3-7.5': 1,
#          u'6.3-8.0': 1,
#          u'6.3-8.2': 1,
#          u'6.3-8.5': 2,
#          u'6.3-8.6': 1,
#          u'6.3-9.8': 1,
#          u'6.34': 8,
#          u'6.37': 1,
#          u'6.4-10.0': 1,
#          u'6.4-7.8': 2,
#          u'6.4-7.9': 2,
#          u'6.4-8.1': 1,
#          u'6.4-8.2': 1,
#          u'6.4-8.3': 1,
#          u'6.4-8.5': 1,
#          u'6.4-8.8': 1,
#          u'6.5': 10,
#          u'6.5 - 6.7': 1,
#          u'6.5 - 7': 1,
#          u'6.5 - 7.0': 2,
#          u'6.5 - 7.5': 1,
#          u'6.5 - 8': 3,
#          u'6.5 - 8.0': 2,
#          u'6.5 - 8.5': 1,
#          u'6.5 - 8.6': 1,
#          u'6.5 - 9.5': 1,
#          u'6.5 ? 9.1': 1,
#          u'6.5-10.0': 1,
#          u'6.5-11.5': 1,
#          u'6.5-6.8': 1,
#          u'6.5-7.0': 4,
#          u'6.5-7.2': 1,
#          u'6.5-7.3': 2,
#          u'6.5-7.5': 7,
#          u'6.5-8': 1,
#          u'6.5-8.0': 4,
#          u'6.5-8.2': 1,
#          u'6.5-8.4': 2,
#          u'6.5-8.5': 8,
#          u'6.5-9.0': 1,
#          u'6.5-9.3': 1,
#          u'6.5-9.4': 1,
#          u'6.5-9.6': 1,
#          u'6.5-9.8': 1,
#          u'6.6': 2,
#          u'6.6 - 7.3': 1,
#          u'6.6-8.4': 1,
#          u'6.65': 2,
#          u'6.7-7.1': 1,
#          u'6.7-8.0': 1,
#          u'6.7-8.2': 2,
#          u'6.7-8.3': 1,
#          u'6.7-8.5': 1,
#          u'6.7-9.7': 1,
#          u'6.71': 4,
#          u'6.8': 8,
#          u'6.8 - 7.0': 3,
#          u'6.8 - 7.8': 2,
#          u'6.8 - 8.0': 1,
#          u'6.8-12.0': 1,
#          u'6.8-7.0': 1,
#          u'6.8-7.2': 4,
#          u'6.8-7.4': 2,
#          u'6.8-7.5': 4,
#          u'6.8-8.0': 2,
#          u'6.8-8.2': 1,
#          u'6.8-8.8': 1,
#          u'6.83': 34,
#          u'6.9': 1,
#          u'6.9-7.1': 1,
#          u'6.9-7.4': 1,
#          u'6.9-7.5': 2,
#          u'6.9-7.6': 1,
#          u'6.9-8.5': 1,
#          u'6.9-9.9': 2,
#          u'7': 90,
#          u'7 - 7.2': 1,
#          u'7 - 7.5': 1,
#          u'7 - 8': 2,
#          u'7 - 8.5': 1,
#          u'7 - 9': 1,
#          u'7,3': 1,
#          u'7-10': 6,
#          u'7-10.5': 1,
#          u'7-11': 4,
#          u'7-7.2': 2,
#          u'7-7.6': 1,
#          u'7-8': 17,
#          u'7-9': 12,
#          u'7.0': 34,
#          u'7.0 - 7.2': 1,
#          u'7.0 - 7.3': 1,
#          u'7.0 - 7.5': 3,
#          u'7.0 - 8.0': 2,
#          u'7.0-10.0': 1,
#          u'7.0-10.5': 1,
#          u'7.0-11.0': 1,
#          u'7.0-11.1': 1,
#          u'7.0-12.5': 1,
#          u'7.0-13.0': 1,
#          u'7.0-7.5': 4,
#          u'7.0-7.5 um': 1,
#          u'7.0-7.6': 1,
#          u'7.0-7.9': 2,
#          u'7.0-8.0': 1,
#          u'7.0-8.5': 1,
#          u'7.03': 17,
#          u'7.08': 2,
#          u'7.1 - 7.5': 1,
#          u'7.1-7.4': 1,
#          u'7.1-7.9': 1,
#          u'7.2': 10,
#          u'7.2-10.2': 1,
#          u'7.2-7.5': 1,
#          u'7.29': 5,
#          u'7.3': 2,
#          u'7.3-7.6': 6,
#          u'7.30': 2,
#          u'7.32': 6,
#          u'7.4': 20,
#          u'7.4-8.0': 1,
#          u'7.5': 17,
#          u'7.5 - 10.2': 1,
#          u'7.5 - 7.8': 4,
#          u'7.5 - 7.9': 1,
#          u'7.5 - 8.0': 2,
#          u'7.5 - 8.5': 1,
#          u'7.5-10.2': 2,
#          u'7.5-10.5': 1,
#          u'7.5-10.7': 2,
#          u'7.5-12': 1,
#          u'7.5-7.8': 1,
#          u'7.5-8': 5,
#          u'7.5-8.0': 7,
#          u'7.5-8.5': 4,
#          u'7.5-9.0': 1,
#          u'7.6': 1,
#          u'7.6 - 8.0': 4,
#          u'7.6- 8.0': 1,
#          u'7.72': 2,
#          u'7.8-10.0': 2,
#          u'7.8-8.2': 1,
#          u'7.9': 1,
#          u'7.94': 15,
#          u'8': 29,
#          u'8 - 10': 2,
#          u'8 - 10.2': 1,
#          u'8-12': 1,
#          u'8-9': 2,
#          u'8.0': 11,
#          u'8.0 - 8.5': 2,
#          u'8.0-10.2': 1,
#          u'8.0-10.5': 1,
#          u'8.0-12.0': 1,
#          u'8.0-14.0': 1,
#          u'8.0-8.5': 1,
#          u'8.0-9.15': 1,
#          u'8.1-9.1': 1,
#          u'8.14': 1,
#          u'8.15': 1,
#          u'8.17': 6,
#          u'8.3': 2,
#          u'8.4': 2,
#          u'8.5': 8,
#          u'8.5-9.0': 2,
#          u'8.6-10.4': 1,
#          u'8.8': 2,
#          u'8.8 - 9.7': 1,
#          u'9': 4,
#          u'9 - 9..5': 1,
#          u'9.0': 4,
#          u'9.1': 2,
#          u'9.5': 4,
#          u'9.6 - 10': 1,
#          u'9.8': 1,
#          u'Neutral': 4,
#          u'acido-sensible': 2,
#          u'circumneutral': 14,
#          u'neutral': 3,
#          u'range 5.5?8.5; opt 6.5': 1,
#          u'zzz': 64059,
#          u'~4.5': 1})

# %%
collections.Counter([entry['pH'] for entry in eukarya_metadata['records']])
# Out:
# Counter({u'7': 2, u'7.5': 1, u'zzz': 702})

# %%
collections.Counter([entry['Salinity'] for entry in archaea_metadata['records']])
# Out:
# Counter({u'0.16-0.22 M': 3,
#          u'Halophile': 110,
#          u'Halotolerant': 1,
#          u'zzz': 1511})

# %%
collections.Counter([entry['pH'] for entry in bacteria_metadata['records']])
# Out:
# Counter({u'1.3 - 4.0': 1,
#          u'1.8': 2,
#          u'1.9': 1,
#          u'10': 1,
#          u'11.0': 1,
#          u'2': 3,
#          u'2-2.5 (optimum)': 1,
#          u'2.5': 1,
#          u'3': 4,
#          u'3 - 4': 2,
#          u'3.1-6.5, optimum 4.5-5.0': 1,
#          u'3.2-7.5': 1,
#          u'3.5 - 9.0': 1,
#          u'3.5-3.8': 1,
#          u'3.5-6.0': 1,
#          u'3.6': 1,
#          u'3.6 - 7.8': 1,
#          u'3.6-6.9': 1,
#          u'3.7-7.1': 1,
#          u'3.8-9.0': 1,
#          u'3.85 - 6.35': 1,
#          u'3.9': 1,
#          u'4 - 10': 1,
#          u'4 - 4.5': 1,
#          u'4 - 5': 1,
#          u'4-10': 2,
#          u'4-4.5': 1,
#          u'4-5': 3,
#          u'4-6': 1,
#          u'4-7': 1,
#          u'4-8': 2,
#          u'4-9': 4,
#          u'4-9.6': 2,
#          u'4.0-8.0': 1,
#          u'4.0-8.5': 3,
#          u'4.0-9.0': 1,
#          u'4.0-9.5': 4,
#          u'4.1-7.8': 2,
#          u'4.19': 13,
#          u'4.2 - 7.2': 1,
#          u'4.2 - 8.2': 1,
#          u'4.2-8.3': 1,
#          u'4.29': 3,
#          u'4.3': 1,
#          u'4.5': 7,
#          u'4.5 - 7': 1,
#          u'4.5 - 7.1': 2,
#          u'4.5 - 9.0': 1,
#          u'4.5-12.0': 1,
#          u'4.5-5.0': 1,
#          u'4.5-7.0': 1,
#          u'4.5-8': 3,
#          u'4.5-8.0': 1,
#          u'4.5-8.4': 1,
#          u'4.5-8.5': 2,
#          u'4.7 - 8.8': 1,
#          u'4.7-9.5': 1,
#          u'4.8 - 6.8': 1,
#          u'4.8-8.6': 1,
#          u'4.9-5.4': 1,
#          u'4.9-6.8': 1,
#          u'5': 2,
#          u'5 - 10': 1,
#          u'5 - 6.2': 2,
#          u'5 - 7': 2,
#          u'5 - 7.5': 1,
#          u'5 - 9': 1,
#          u'5- 10': 1,
#          u'5-10': 14,
#          u'5-11': 2,
#          u'5-12': 2,
#          u'5-7': 2,
#          u'5-8': 121,
#          u'5-8.5': 1,
#          u'5-9': 15,
#          u'5-9.5': 1,
#          u'5.0': 1,
#          u'5.0- 10.0; 6.0- 7.0': 3,
#          u'5.0-10.0': 1,
#          u'5.0-10.5': 1,
#          u'5.0-6.5': 2,
#          u'5.0-8.0': 1,
#          u'5.0-8.5': 6,
#          u'5.0-9.0': 1,
#          u'5.0-9.5': 2,
#          u'5.0-9.8': 1,
#          u'5.1-8.0': 1,
#          u'5.1-9.1': 1,
#          u'5.2-7.4': 1,
#          u'5.2-8.6': 1,
#          u'5.3': 1,
#          u'5.3 - 7.6': 1,
#          u'5.3- 7.2': 2,
#          u'5.3-5.5': 2,
#          u'5.3-8.8': 1,
#          u'5.3-9.3': 1,
#          u'5.4-7.5': 1,
#          u'5.4-8.4': 1,
#          u'5.4-8.9': 1,
#          u'5.5': 5,
#          u'5.5 - 10': 1,
#          u'5.5 - 7.5': 5,
#          u'5.5 - 9.5': 1,
#          u'5.5 -7.5': 1,
#          u'5.5-10.0': 2,
#          u'5.5-10.00 (optimum 7.5)': 1,
#          u'5.5-10.5': 1,
#          u'5.5-11': 1,
#          u'5.5-11.0': 3,
#          u'5.5-12.0': 1,
#          u'5.5-12.5': 1,
#          u'5.5-6.0': 2,
#          u'5.5-7.5': 5,
#          u'5.5-8.0': 4,
#          u'5.5-8.3': 1,
#          u'5.5-8.5': 6,
#          u'5.5-8.6': 1,
#          u'5.5-9.0': 9,
#          u'5.5-9.3': 1,
#          u'5.5-9.5': 5,
#          u'5.5-9.7': 1,
#          u'5.6 - 10.1': 1,
#          u'5.6-7.8': 1,
#          u'5.6-8.3': 3,
#          u'5.6-8.4': 2,
#          u'5.6-8.6': 2,
#          u'5.6-9.8': 1,
#          u'5.7 - 6.2': 1,
#          u'5.7-10.0': 1,
#          u'5.7-6.7': 1,
#          u'5.7-8.0': 2,
#          u'5.8 - 6.2': 1,
#          u'5.8 - 8.2': 2,
#          u'5.8-10.0': 1,
#          u'5.8-11': 1,
#          u'5.8-7.8': 1,
#          u'5.8-8.0': 1,
#          u'5.8-8.2': 1,
#          u'5.8-8.8': 1,
#          u'5.8-9.0': 1,
#          u'5.9': 2,
#          u'5.9-8.2': 1,
#          u'5.9-8.8': 2,
#          u'5.9-9.0': 1,
#          u'5.91': 2,
#          u'6': 6,
#          u'6 - 10': 1,
#          u'6 - 6.5': 1,
#          u'6 - 7': 1,
#          u'6 - 8': 2,
#          u'6 - 9': 2,
#          u'6 - 9.2': 1,
#          u'6-10': 15,
#          u'6-11': 8,
#          u'6-12': 1,
#          u'6-7': 7,
#          u'6-8': 27,
#          u'6-9': 34,
#          u'6-9.5': 2,
#          u'6.0': 2,
#          u'6.0 - 10.0': 1,
#          u'6.0 - 7.0': 2,
#          u'6.0 - 8.0': 2,
#          u'6.0 - 8.2': 2,
#          u'6.0 - 9.0': 1,
#          u'6.0 - 9.5': 1,
#          u'6.0-10.0': 3,
#          u'6.0-10.5': 3,
#          u'6.0-6.5': 1,
#          u'6.0-7.0': 1,
#          u'6.0-7.2': 1,
#          u'6.0-7.5': 6,
#          u'6.0-7.8': 1,
#          u'6.0-8.0': 2,
#          u'6.0-8.1': 1,
#          u'6.0-8.2': 1,
#          u'6.0-8.5': 4,
#          u'6.0-8.6': 1,
#          u'6.0-9.5': 3,
#          u'6.0-9.7': 1,
#          u'6.1-10.1': 1,
#          u'6.1-7.5': 1,
#          u'6.1-8.1': 1,
#          u'6.1-8.2': 2,
#          u'6.2-7': 10,
#          u'6.2-8.0': 2,
#          u'6.2-8.2': 1,
#          u'6.2-8.7': 1,
#          u'6.2-8.9': 1,
#          u'6.25': 1,
#          u'6.25-7.5': 1,
#          u'6.3': 43,
#          u'6.3 - 7.4': 2,
#          u'6.3 - 7.5': 1,
#          u'6.3 - 9.3': 1,
#          u'6.3-7.5': 1,
#          u'6.3-8.0': 1,
#          u'6.3-8.2': 1,
#          u'6.3-8.5': 2,
#          u'6.3-8.6': 1,
#          u'6.3-9.8': 1,
#          u'6.34': 8,
#          u'6.37': 1,
#          u'6.4-10.0': 1,
#          u'6.4-7.8': 2,
#          u'6.4-7.9': 2,
#          u'6.4-8.1': 1,
#          u'6.4-8.2': 1,
#          u'6.4-8.3': 1,
#          u'6.4-8.5': 1,
#          u'6.4-8.8': 1,
#          u'6.5': 10,
#          u'6.5 - 6.7': 1,
#          u'6.5 - 7': 1,
#          u'6.5 - 7.0': 2,
#          u'6.5 - 7.5': 1,
#          u'6.5 - 8': 3,
#          u'6.5 - 8.0': 2,
#          u'6.5 - 8.5': 1,
#          u'6.5 - 8.6': 1,
#          u'6.5 - 9.5': 1,
#          u'6.5 ? 9.1': 1,
#          u'6.5-10.0': 1,
#          u'6.5-11.5': 1,
#          u'6.5-6.8': 1,
#          u'6.5-7.0': 4,
#          u'6.5-7.2': 1,
#          u'6.5-7.3': 2,
#          u'6.5-7.5': 7,
#          u'6.5-8': 1,
#          u'6.5-8.0': 4,
#          u'6.5-8.2': 1,
#          u'6.5-8.4': 2,
#          u'6.5-8.5': 8,
#          u'6.5-9.0': 1,
#          u'6.5-9.3': 1,
#          u'6.5-9.4': 1,
#          u'6.5-9.6': 1,
#          u'6.5-9.8': 1,
#          u'6.6': 2,
#          u'6.6 - 7.3': 1,
#          u'6.6-8.4': 1,
#          u'6.65': 2,
#          u'6.7-7.1': 1,
#          u'6.7-8.0': 1,
#          u'6.7-8.2': 2,
#          u'6.7-8.3': 1,
#          u'6.7-8.5': 1,
#          u'6.7-9.7': 1,
#          u'6.71': 4,
#          u'6.8': 8,
#          u'6.8 - 7.0': 3,
#          u'6.8 - 7.8': 2,
#          u'6.8 - 8.0': 1,
#          u'6.8-12.0': 1,
#          u'6.8-7.0': 1,
#          u'6.8-7.2': 4,
#          u'6.8-7.4': 2,
#          u'6.8-7.5': 4,
#          u'6.8-8.0': 2,
#          u'6.8-8.2': 1,
#          u'6.8-8.8': 1,
#          u'6.83': 34,
#          u'6.9': 1,
#          u'6.9-7.1': 1,
#          u'6.9-7.4': 1,
#          u'6.9-7.5': 2,
#          u'6.9-7.6': 1,
#          u'6.9-8.5': 1,
#          u'6.9-9.9': 2,
#          u'7': 90,
#          u'7 - 7.2': 1,
#          u'7 - 7.5': 1,
#          u'7 - 8': 2,
#          u'7 - 8.5': 1,
#          u'7 - 9': 1,
#          u'7,3': 1,
#          u'7-10': 6,
#          u'7-10.5': 1,
#          u'7-11': 4,
#          u'7-7.2': 2,
#          u'7-7.6': 1,
#          u'7-8': 17,
#          u'7-9': 12,
#          u'7.0': 34,
#          u'7.0 - 7.2': 1,
#          u'7.0 - 7.3': 1,
#          u'7.0 - 7.5': 3,
#          u'7.0 - 8.0': 2,
#          u'7.0-10.0': 1,
#          u'7.0-10.5': 1,
#          u'7.0-11.0': 1,
#          u'7.0-11.1': 1,
#          u'7.0-12.5': 1,
#          u'7.0-13.0': 1,
#          u'7.0-7.5': 4,
#          u'7.0-7.5 um': 1,
#          u'7.0-7.6': 1,
#          u'7.0-7.9': 2,
#          u'7.0-8.0': 1,
#          u'7.0-8.5': 1,
#          u'7.03': 17,
#          u'7.08': 2,
#          u'7.1 - 7.5': 1,
#          u'7.1-7.4': 1,
#          u'7.1-7.9': 1,
#          u'7.2': 10,
#          u'7.2-10.2': 1,
#          u'7.2-7.5': 1,
#          u'7.29': 5,
#          u'7.3': 2,
#          u'7.3-7.6': 6,
#          u'7.30': 2,
#          u'7.32': 6,
#          u'7.4': 20,
#          u'7.4-8.0': 1,
#          u'7.5': 17,
#          u'7.5 - 10.2': 1,
#          u'7.5 - 7.8': 4,
#          u'7.5 - 7.9': 1,
#          u'7.5 - 8.0': 2,
#          u'7.5 - 8.5': 1,
#          u'7.5-10.2': 2,
#          u'7.5-10.5': 1,
#          u'7.5-10.7': 2,
#          u'7.5-12': 1,
#          u'7.5-7.8': 1,
#          u'7.5-8': 5,
#          u'7.5-8.0': 7,
#          u'7.5-8.5': 4,
#          u'7.5-9.0': 1,
#          u'7.6': 1,
#          u'7.6 - 8.0': 4,
#          u'7.6- 8.0': 1,
#          u'7.72': 2,
#          u'7.8-10.0': 2,
#          u'7.8-8.2': 1,
#          u'7.9': 1,
#          u'7.94': 15,
#          u'8': 29,
#          u'8 - 10': 2,
#          u'8 - 10.2': 1,
#          u'8-12': 1,
#          u'8-9': 2,
#          u'8.0': 11,
#          u'8.0 - 8.5': 2,
#          u'8.0-10.2': 1,
#          u'8.0-10.5': 1,
#          u'8.0-12.0': 1,
#          u'8.0-14.0': 1,
#          u'8.0-8.5': 1,
#          u'8.0-9.15': 1,
#          u'8.1-9.1': 1,
#          u'8.14': 1,
#          u'8.15': 1,
#          u'8.17': 6,
#          u'8.3': 2,
#          u'8.4': 2,
#          u'8.5': 8,
#          u'8.5-9.0': 2,
#          u'8.6-10.4': 1,
#          u'8.8': 2,
#          u'8.8 - 9.7': 1,
#          u'9': 4,
#          u'9 - 9..5': 1,
#          u'9.0': 4,
#          u'9.1': 2,
#          u'9.5': 4,
#          u'9.6 - 10': 1,
#          u'9.8': 1,
#          u'Neutral': 4,
#          u'acido-sensible': 2,
#          u'circumneutral': 14,
#          u'neutral': 3,
#          u'range 5.5?8.5; opt 6.5': 1,
#          u'zzz': 64059,
#          u'~4.5': 1})

# %%
range(3)[::-1]
# Out:
# [2, 1, 0]

# %%
if 1 and 0:
    print True

# %%
## Tested and works
def check_overlap_number(range_1,i):
    if (i>=min(range_1)) and (i<=max(range_1)):
        return True
    else:
        return False

# %%
check_overlap_number((9.0,11.0),9.0)
# Out:
# True

# %%
## Tested and works
def check_overlap_ranges(range_1,range_2):
    # order the ranges so that the range with the smallest min is first
    # check if the min of range2 is less than the max of range 1
    ranges = [range_1,range_2]
    if min(range_2)<min(range_1):
        ranges = ranges[::-1]
    if min(ranges[1])<=max(ranges[0]):
        return True
    else:
        return False

# %%
def get_entries_within_ph_range(records, desired_ph_range):
    entries_with_phs_in_range = list()
    for entry in records:
        in_desired_ph_range = False
        ph_range_str = entry['pH'].split('-')

        if len(ph_range_str) == 1:
            try:
                ph = float(ph_range_str[0])
                in_desired_ph_range = check_overlap_number(desired_ph_range,ph)

            except:
                pass
        elif len(ph_range_str) == 2:
            try:
                ph_min = float(ph_range_str[0])
                ph_max = float(ph_range_str[1])
                ph = (ph_min,ph_max)
                in_desired_ph_range = check_overlap_ranges(desired_ph_range,ph)
            except:
                pass
        
        if in_desired_ph_range == True:
            entries_with_phs_in_range.append(entry)
    
    return entries_with_phs_in_range

# %%
def format_urls_for_scraping(homepage_url,entries_with_phs_in_range):
    all_GenomeNameSampleNameDisp =  [d['GenomeNameSampleNameDisp'] for d in entries_with_phs_in_range]

    organism_urls = list()

    for htmlandjunk in all_GenomeNameSampleNameDisp:
        regex = r"<a href='main\.cgi(.*)'>"
        match = re.search(regex, htmlandjunk)
        html_suffix = match.group(1)
        full_url = homepage_url+html_suffix
        organism_urls.append(full_url)

    return organism_urls

# %%
records = bacteria_metadata['records']
ph_range = (9.0,11.0)

entries_with_phs_in_range = get_entries_within_ph_range(records,ph_range)

# %%
len(entries_with_phs_in_range)
# Out:
# 266

# %%
## 266 bacteria vs. 56 that were successfully scraped
print len(get_entries_within_ph_range(bacteria_metadata['records'],ph_range))
print len(glob.glob('../jgi/2018-09-29/ph_jsons/bacteria/*.json'))
# Out:
# 266
# 56

# %%
## 28 archaea vs. 28 that were successfully scraped
print len(get_entries_within_ph_range(archaea_metadata['records'],ph_range))
print len(glob.glob('../jgi/2018-09-29/ph_jsons/archaea/*.json'))
# Out:
# 28
# 28

# %%
records

# %%
homepage_url = 'https://img.jgi.doe.gov/cgi-bin/m/main.cgi'
format_urls_for_scraping(homepage_url,entries_with_phs_in_range)
# Out:
# []

# %%
for entry in entries_with_phs_in_range:
    print entry['GenomeNameSampleNameDisp']
# Out:
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2523533532'>Actinomadura rifamycini DSM 43936</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2524614884'>Ornithinimicrobium pekingense DSM 21552</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2518645608'>Saccharibacillus kuerlensis DSM 22868</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2582581268'>Halomonas ilicicola DSM 19980</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2574180435'>Atlantibacter subterranea DSM 16208</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2565956515'>Pararheinheimera texasensis DSM 17496</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2518645611'>Halomonas lutea DSM 23508</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=
a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2558309000'>Simplicispira psychrophila DSM 11588</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2524023149'>Agrococcus lahaulensis DSM 17612</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2519899640'>Salinicoccus albus DSM 19776</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2551306473'>Pedobacter arcticus A12</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2513237119'>Thermocrispum municipale DSM 44069</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=651324017'>Caldalkalibacillus thermarum TA2.A1</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2523533536'>Chryseobacterium daeguense DSM 19388</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2574179706'>Desulfovibrio vietnamensis DSM 10520</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2579778672'>Comamonadaceae bacterium H1</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2568526002'>Andreprevotia lacus DSM 23236</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2524023187'>Agromyces subbeticus DSM 16689</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2515154073'>Dasania marina DSM 21967</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2522572188'>Salinarimonas rosea DSM 21201</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2585428173'>Anaerocolumna jejuensis DSM 15929</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2599185148'>Geoalkalibacter ferrihydriticus DSM 17813</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2517572148'>Bacillus fordii DSM 16014</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2571042005'>Deinococcus misasensis DSM 22328</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2556921652'>Halotalea alkalilenta DSM 17697</a>
# <a href='main.cgi?section=TaxonDetail&page=taxonDetail&taxon_oid=2519899682'>Deinococcus aquatilis DSM 23025</a>

# %%
[i['pH'] for i in entries_with_phs_in_range]
# Out:
# [u'6-12',
#  u'6-9',
#  u'5-10',
#  u'6-9',
#  u'4.0-9.5',
#  u'6.5-9.6',
#  u'5-9',
#  u'8.1-9.1',
#  u'5.5-9.0',
#  u'6-9.5',
#  u'6.4-10.0',
#  u'9.0',
#  u'7.2-10.2',
#  u'5-9',
#  u'6-11',
#  u'4.0-9.0',
#  u'6-9',
#  u'5.6-9.8',
#  u'7.5-10.2',
#  u'5-10',
#  u'4.0-9.5',
#  u'9.1',
#  u'7-9',
#  u'7-11',
#  u'6-11',
#  u'9.0',
#  u'5.5-10.0',
#  u'6-10',
#  u'5.5-12.0',
#  u'9.5',
#  u'6-10',
#  u'6-9',
#  u'5-10',
#  u'6.0-9.5',
#  u'6.0-10.0',
#  u'4.5 - 9.0',
#  u'7-9',
#  u'6.5-11.5',
#  u'5-11',
#  u'6-10',
#  u'6.5-9.0',
#  u'6-9',
#  u'4-9',
#  u'5-10',
#  u'7.5-9.0',
#  u'4-9',
#  u'5-10',
#  u'6-11',
#  u'6-9',
#  u'7-9',
#  u'8.6-10.4',
#  u'5.5-9.5',
#  u'5.5-10.0',
#  u'5-9',
#  u'6.0 - 9.5',
#  u'5 - 9',
#  u'7-10',
#  u'5.1-9.1',
#  u'6-9',
#  u'5.0-9.0',
#  u'8 - 10',
#  u'6.5-9.3',
#  u'6 - 9',
#  u'6.0 - 10.0',
#  u'6-9',
#  u'5.5-11.0',
#  u'6-10',
#  u'6-11',
#  u'5-9.5',
#  u'6.0-10.0',
#  u'5.5 - 9.5',
#  u'6.7-9.7',
#  u'6.0-9.7',
#  u'6-10',
#  u'6-9',
#  u'5.8-10.0',
#  u'7-10',
#  u'7.5-10.2',
#  u'7-11',
#  u'5.0-9.5',
#  u'5-9',
#  u'9',
#  u'5-10',
#  u'7-10',
#  u'4-9.6',
#  u'5-10',
#  u'6-11',
#  u'6 - 9',
#  u'9.0',
#  u'6-9',
#  u'10',
#  u'7-10',
#  u'5-9',
#  u'5.5-9.0',
#  u'4.0-9.5',
#  u'6-10',
#  u'6-10',
#  u'6-9',
#  u'7-10.5',
#  u'5-9',
#  u'9.0',
#  u'6.5 - 9.5',
#  u'6-9',
#  u'6-9',
#  u'6-10',
#  u'7-9',
#  u'5.5-9.0',
#  u'5-10',
#  u'5-9',
#  u'5.5-9.5',
#  u'6.0-10.0',
#  u'7-11',
#  u'8.0-10.2',
#  u'4-9',
#  u'6.9-9.9',
#  u'8.0-10.5',
#  u'9.1',
#  u'4.5-12.0',
#  u'5-10',
#  u'7.0-12.5',
#  u'6-9',
#  u'6-10',
#  u'7.8-10.0',
#  u'5-9',
#  u'5-9',
#  u'5.0-10.0',
#  u'4-10',
#  u'6.0-9.5',
#  u'6.3 - 9.3',
#  u'9.6 - 10',
#  u'6.0-10.5',
#  u'5-9',
#  u'7-10',
#  u'5.5-9.0',
#  u'4-9.6',
#  u'6.1-10.1',
#  u'4.7-9.5',
#  u'6 - 9.2',
#  u'5-9',
#  u'6.5-10.0',
#  u'5.9-9.0',
#  u'7.0-11.0',
#  u'8.0-12.0',
#  u'8.8 - 9.7',
#  u'6.0-10.5',
#  u'7.0-11.1',
#  u'5-10',
#  u'8-12',
#  u'6.0-9.5',
#  u'6-11',
#  u'7-9',
#  u'6-9',
#  u'8.5-9.0',
#  u'5.5-9.5',
#  u'5.7-10.0',
#  u'4-10',
#  u'5.6 - 10.1',
#  u'5-9',
#  u'4.0-9.5',
#  u'5.8-9.0',
#  u'5.5-9.0',
#  u'6-9',
#  u'6.5-9.4',
#  u'7-11',
#  u'6-9',
#  u'7.0-10.5',
#  u'6.0 - 9.0',
#  u'3.5 - 9.0',
#  u'6-9',
#  u'8.0-14.0',
#  u'5-12',
#  u'8.0-9.15',
#  u'7.0-13.0',
#  u'6.9-9.9',
#  u'5-9',
#  u'5.5-9.5',
#  u'6-9',
#  u'6.3-9.8',
#  u'6-10',
#  u'6-9',
#  u'6-10',
#  u'5-9',
#  u'6-9',
#  u'6.5-9.8',
#  u'7-9',
#  u'5.5-11.0',
#  u'5-12',
#  u'5-10',
#  u'6 - 10',
#  u'5.5-10.5',
#  u'6-10',
#  u'6-9',
#  u'9.5',
#  u'6-9',
#  u'5.5-9.3',
#  u'7-9',
#  u'8 - 10.2',
#  u'7-9',
#  u'6-9',
#  u'5.0-10.5',
#  u'9.5',
#  u'6.0-10.5',
#  u'5.0-9.8',
#  u'8-9',
#  u'7-9',
#  u'7 - 9',
#  u'5.5-12.5',
#  u'5.5-9.0',
#  u'5- 10',
#  u'9',
#  u'6-11',
#  u'7-10',
#  u'6-9',
#  u'6-9',
#  u'4-9',
#  u'7.5-10.7',
#  u'4 - 10',
#  u'5-10',
#  u'8.5-9.0',
#  u'6.8-12.0',
#  u'6-9',
#  u'5.3-9.3',
#  u'6-9',
#  u'5-10',
#  u'6-9',
#  u'5.5-11.0',
#  u'5.5 - 10',
#  u'5.5-9.0',
#  u'8-9',
#  u'9',
#  u'5-9',
#  u'9.8',
#  u'7-9',
#  u'5 - 10',
#  u'5.5-9.7',
#  u'6-9',
#  u'7-9',
#  u'6-9',
#  u'3.8-9.0',
#  u'7.5-12',
#  u'7.5 - 10.2',
#  u'6-9',
#  u'6-9.5',
#  u'7.5-10.7',
#  u'8 - 10',
#  u'5.8-11',
#  u'7.5-10.5',
#  u'5.5-9.0',
#  u'6-10',
#  u'6-10',
#  u'6-9',
#  u'6-11',
#  u'9.5',
#  u'5.5-9.0',
#  u'5-10',
#  u'11.0',
#  u'7-9',
#  u'5.0-9.5',
#  u'7.0-10.0',
#  u'6-9',
#  u'5.5-9.5',
#  u'7.8-10.0',
#  u'9',
#  u'6-10',
#  u'5-11',
#  u'5.5-11']

# %%
for i in collections.Counter([entry['pH'] for entry in bacteria_metadata['records']]):
    if len(i.split('-')) == 1:
        try:
            pH = float(i.split('-')[0])
            print pH
#         check_if_within_ph_range()
        except:
            pass
    else:
        try:
            ph_min = float(i.split('-')[0])
            ph_max = float(i.split('-')[1])
            print (ph_min,ph_max)
        except:
            pass
# Out:
# (6.8, 7.0)
# (6.0, 8.1)
# (6.5, 6.7)
# (6.0, 10.0)
# (5.7, 10.0)
# (8.0, 10.2)
# (8.0, 10.5)
# (6.0, 7.0)
# (7.0, 11.0)
# (7.0, 11.1)
# (6.0, 9.5)
# (4.2, 7.2)
# (7.0, 13.0)
# (7.0, 8.0)
# (4.0, 5.0)
# (5.3, 9.3)
# (8.0, 10.0)
# (7.5, 12.0)
# (5.2, 8.6)
# (7.0, 8.5)
# (6.5, 8.0)
# (5.0, 6.5)
# (5.8, 9.0)
# (5.9, 9.0)
# 6.71
# (8.0, 8.5)
# (6.0, 8.0)
# (6.0, 9.0)
# (6.0, 7.0)
# (5.8, 7.8)
# (5.5, 12.0)
# (6.1, 10.1)
# (7.6, 8.0)
# (6.8, 8.2)
# (4.0, 5.0)
# (6.8, 8.0)
# (6.8, 8.8)
# (5.0, 6.2)
# (6.5, 8.5)
# (5.1, 9.1)
# (6.5, 8.0)
# (5.0, 9.0)
# (6.7, 8.0)
# (6.7, 8.3)
# (6.0, 7.2)
# (6.0, 7.5)
# (6.0, 7.8)
# (8.0, 8.5)
# (5.0, 8.0)
# (5.0, 8.5)
# (8.1, 9.1)
# (4.0, 9.0)
# (4.0, 9.5)
# (3.5, 3.8)
# (6.6, 8.4)
# (7.5, 8.0)
# (6.4, 8.8)
# (5.8, 8.0)
# (6.4, 8.5)
# (6.4, 8.2)
# (6.4, 8.3)
# (6.4, 8.1)
# (6.0, 9.7)
# (6.5, 9.3)
# (6.5, 9.0)
# (5.8, 8.2)
# (6.5, 9.6)
# (6.5, 9.4)
# (5.5, 7.5)
# (6.5, 9.8)
# (5.5, 10.5)
# (5.5, 10.0)
# (1.3, 4.0)
# (5.6, 8.3)
# (5.6, 8.6)
# (5.6, 8.4)
# (6.8, 8.0)
# (6.0, 10.0)
# (6.0, 11.0)
# (6.0, 12.0)
# 5.3
# 5.5
# 5.9
# (4.5, 8.0)
# (6.2, 7.0)
# (6.0, 10.0)
# 5.0
# (3.7, 7.1)
# (5.5, 10.0)
# (6.5, 7.0)
# (6.5, 8.0)
# (6.0, 10.0)
# (5.5, 11.0)
# (6.1, 8.2)
# (6.1, 8.1)
# 11.0
# 6.6
# 6.5
# 6.3
# 6.0
# 6.9
# 6.8
# (7.5, 7.9)
# 6.34
# 6.37
# (7.8, 10.0)
# 7.03
# (6.5, 11.5)
# (6.5, 7.5)
# (6.5, 7.0)
# (6.5, 7.2)
# (6.5, 7.3)
# (7.0, 10.5)
# (6.3, 8.5)
# (6.3, 8.6)
# (6.3, 8.0)
# (6.3, 8.2)
# (4.9, 5.4)
# (5.0, 10.0)
# (6.9, 7.1)
# (6.9, 7.4)
# (6.9, 7.5)
# (6.9, 7.6)
# (8.6, 10.4)
# (7.1, 7.5)
# 7.0
# (5.0, 10.0)
# (5.0, 10.5)
# (6.3, 9.3)
# (4.5, 8.4)
# (6.7, 8.5)
# (8.0, 9.0)
# (4.7, 9.5)
# (4.8, 6.8)
# (3.2, 7.5)
# (6.9, 9.9)
# (5.5, 7.5)
# (7.0, 8.0)
# (7.5, 7.8)
# (5.0, 8.5)
# (6.3, 7.4)
# (6.3, 7.5)
# (5.5, 9.0)
# (5.5, 9.3)
# 2.0
# (5.5, 9.5)
# (5.5, 9.7)
# (4.5, 5.0)
# (8.5, 9.0)
# (5.0, 10.0)
# (5.0, 12.0)
# (5.4, 8.9)
# (5.4, 8.4)
# 5.91
# (7.5, 10.5)
# (6.8, 7.2)
# (7.5, 10.7)
# (7.5, 10.2)
# (4.7, 8.8)
# 10.0
# (7.5, 9.0)
# (4.2, 8.3)
# (4.5, 7.0)
# (6.8, 7.5)
# (5.0, 11.0)
# (8.0, 10.2)
# 1.9
# (6.2, 8.7)
# (6.2, 8.0)
# (6.2, 8.2)
# (4.8, 8.6)
# (6.2, 8.9)
# (3.6, 7.8)
# (5.4, 7.5)
# (5.8, 10.0)
# (6.4, 7.9)
# (6.4, 7.8)
# (5.0, 7.0)
# (5.0, 9.0)
# (5.0, 8.0)
# (7.4, 8.0)
# 7.2
# 7.3
# 7.0
# 7.6
# 7.4
# 7.5
# 7.9
# (5.8, 8.8)
# 8.0
# (7.2, 7.5)
# (3.85, 6.35)
# (7.0, 7.9)
# (7.0, 7.5)
# (7.0, 7.6)
# (8.0, 12.0)
# (7.0, 11.0)
# (7.0, 10.0)
# (6.0, 8.2)
# (6.0, 9.2)
# (6.0, 8.0)
# (4.0, 4.5)
# (8.0, 9.15)
# 7.32
# 7.3
# (3.5, 9.0)
# (5.6, 10.1)
# (4.0, 10.0)
# (4.5, 12.0)
# (8.8, 9.7)
# 2.5
# (5.3, 7.2)
# (3.0, 4.0)
# (6.5, 7.5)
# (6.5, 7.0)
# 3.0
# (4.5, 9.0)
# (7.0, 10.5)
# (7.0, 10.0)
# (3.5, 6.0)
# (7.0, 12.5)
# (5.5, 7.5)
# (6.6, 7.3)
# (4.0, 4.5)
# (4.2, 8.2)
# (5.3, 8.8)
# (6.5, 8.5)
# (6.5, 8.4)
# (6.5, 8.2)
# (6.5, 8.0)
# (5.5, 12.5)
# (7.0, 7.6)
# (7.0, 7.2)
# 8.0
# 8.3
# 8.5
# 8.4
# 8.8
# (7.0, 7.5)
# (5.9, 8.2)
# (7.0, 7.2)
# (5.9, 8.8)
# (7.5, 7.8)
# (4.1, 7.8)
# (5.3, 7.6)
# 1.8
# (4.5, 7.1)
# (6.0, 8.2)
# (6.0, 10.5)
# (6.0, 8.0)
# (6.7, 7.1)
# (6.0, 8.6)
# (6.8, 7.4)
# (6.0, 8.5)
# (7.0, 9.0)
# 6.83
# (7.8, 8.2)
# (4.0, 6.0)
# (4.0, 7.0)
# (4.0, 8.0)
# (4.0, 9.0)
# (5.7, 8.0)
# (5.8, 8.2)
# (5.0, 10.0)
# (4.5, 7.0)
# (5.8, 6.2)
# (5.0, 7.5)
# (6.5, 9.5)
# (6.0, 6.5)
# (6.7, 9.7)
# (5.1, 8.0)
# (5.0, 9.5)
# (5.7, 6.7)
# (5.0, 9.0)
# (5.0, 9.8)
# (4.0, 8.5)
# (4.0, 8.0)
# 9.0
# (6.5, 6.8)
# (9.6, 10.0)
# (6.0, 7.0)
# (7.1, 7.9)
# (5.2, 7.4)
# (7.1, 7.4)
# 7.08
# (5.5, 6.0)
# (6.0, 8.0)
# (6.0, 9.0)
# (5.5, 11.0)
# (3.6, 6.9)
# 7.72
# (6.4, 10.0)
# (5.6, 9.8)
# (6.5, 8.6)
# (5.0, 7.0)
# (6.8, 7.0)
# 8.15
# 8.14
# 8.17
# (6.8, 7.8)
# (5.8, 11.0)
# (5.5, 8.0)
# (6.0, 9.5)
# (7.5, 8.5)
# (6.25, 7.5)
# (7.5, 8.0)
# (6.0, 7.0)
# (7.0, 9.0)
# (7.0, 8.0)
# (6.7, 8.2)
# (6.9, 8.5)
# (7.2, 10.2)
# (7.6, 8.0)
# 6.65
# 4.19
# 3.6
# 3.9
# (7.0, 7.5)
# (7.0, 7.2)
# (7.0, 7.3)
# 7.29
# (5.7, 6.2)
# (6.5, 10.0)
# 7.94
# (6.3, 7.5)
# (4.0, 10.0)
# (7.0, 8.5)
# (7.0, 8.0)
# (6.1, 7.5)
# (6.3, 9.8)
# (4.5, 8.0)
# (4.5, 8.5)
# (7.3, 7.6)
# (5.6, 7.8)
# 9.8
# 9.5
# 9.0
# 9.1
# 6.0
# (5.5, 9.5)
# (7.5, 8.0)
# (7.5, 8.5)
# (3.8, 9.0)
# (5.3, 5.5)
# (4.9, 6.8)
# (4.0, 9.6)
# (5.0, 9.5)
# 4.5
# 4.3
# (5.5, 8.5)
# (5.5, 8.6)
# 5.0
# (6.8, 12.0)
# (5.5, 8.3)
# (8.0, 12.0)
# (6.0, 6.5)
# (6.0, 9.0)
# (6.0, 9.5)
# 4.29
# (8.0, 14.0)
# (7.5, 10.2)
# 6.25
